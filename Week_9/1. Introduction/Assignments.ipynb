# %%
# import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the dataset
event = pd.read_csv('data/us_holidays.csv')
event.head()
# Out:
#          Date                     Holiday
# 0  02/01/2012              New Year's Day
# 1  16/01/2012  Martin Luther King Jr. Day
# 2  20/02/2012              Presidents Day
# 3  28/05/2012                Memorial Day
# 4  04/07/2012            Independence Day

# %%
event['Time'] = np.arange(len(event.index))

event
# Out:
#           Date                     Holiday  Time
# 0   02/01/2012              New Year's Day     0
# 1   16/01/2012  Martin Luther King Jr. Day     1
# 2   20/02/2012              Presidents Day     2
# 3   28/05/2012                Memorial Day     3
# 4   04/07/2012            Independence Day     4
# 5   03/09/2012                   Labor Day     5
# 6   08/10/2012                Columbus Day     6
# 7   12/11/2012                Veterans Day     7
# 8   22/11/2012                Thanksgiving     8
# 9   25/12/2012               Christmas Day     9
# 10  01/01/2013              New Year's Day    10
# 11  21/01/2013  Martin Luther King Jr. Day    11
# 12  18/02/2013              Presidents Day    12
# 13  27/05/2013                Memorial Day    13
# 14  04/07/2013            Independence Day    14
# 15  02/09/2013                   Labor Day    15
# 16  14/10/2013                Columbus Day    16
# 17  11/11/2013                Veterans Day    17
# ...

# %%
event["Holiday"].value_counts()
# Out:
# New Year's Day                3
# Martin Luther King Jr. Day    3
# Presidents Day                3
# Memorial Day                  3
# Independence Day              3
# Labor Day                     3
# Columbus Day                  3
# Veterans Day                  3
# Thanksgiving                  3
# Christmas Day                 3
# Name: Holiday, dtype: int64

# %%
event["Date"].value_counts()
# Out:
# 02/01/2012    1
# 16/01/2012    1
# 27/11/2014    1
# 11/11/2014    1
# 13/10/2014    1
# 01/09/2014    1
# 04/07/2014    1
# 26/05/2014    1
# 17/02/2014    1
# 20/01/2014    1
# 01/01/2014    1
# 25/12/2013    1
# 28/11/2013    1
# 11/11/2013    1
# 14/10/2013    1
# 02/09/2013    1
# 04/07/2013    1
# 27/05/2013    1
# 18/02/2013    1
# 21/01/2013    1
# 01/01/2013    1
# 25/12/2012    1
# 22/11/2012    1
# 12/11/2012    1
# 08/10/2012    1
# 03/09/2012    1
# 04/07/2012    1
# 28/05/2012    1
# 20/02/2012    1
# 25/12/2014    1
# Name: Date, dtype: int64

# %%
event.columns
# Out:
# Index(['Date', 'Holiday', 'Time'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
new_columns = ['Time', 'Holiday']
events = event.drop([c for c in event.columns if c not in new_columns], axis=1)
events.dropna(inplace=True)
events = events.apply(LabelEncoder().fit_transform)

# %%
events
# Out:
#     Holiday  Time
# 0         6     0
# 1         4     1
# 2         7     2
# 3         5     3
# 4         2     4
# 5         3     5
# 6         1     6
# 7         9     7
# 8         8     8
# 9         0     9
# 10        6    10
# 11        4    11
# 12        7    12
# 13        5    13
# 14        2    14
# 15        3    15
# 16        1    16
# 17        9    17
# 18        8    18
# 19        0    19
# 20        6    20
# 21        4    21
# 22        7    22
# 23        5    23
# 24        2    24
# 25        3    25
# 26        1    26
# 27        9    27
# 28        8    28
# 29        0    29

# %%
events['Time'] = np.arange(len(event.index))

events
# Out:
#     Holiday  Time
# 0         6     0
# 1         4     1
# 2         7     2
# 3         5     3
# 4         2     4
# 5         3     5
# 6         1     6
# 7         9     7
# 8         8     8
# 9         0     9
# 10        6    10
# 11        4    11
# 12        7    12
# 13        5    13
# 14        2    14
# 15        3    15
# 16        1    16
# 17        9    17
# 18        8    18
# 19        0    19
# 20        6    20
# 21        4    21
# 22        7    22
# 23        5    23
# 24        2    24
# 25        3    25
# 26        1    26
# 27        9    27
# 28        8    28
# 29        0    29

# %%
events["Holiday"].plot()
plt.title("the trend of the holiday accroding to time")
plt.show()
